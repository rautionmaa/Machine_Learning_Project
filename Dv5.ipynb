# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm 
import itertools
import sklearn.feature_selection
import sklearn.model_selection as ms
import pickle
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from scipy.stats import skew
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
from scipy import stats
from sklearn.preprocessing import normalize
from scipy.stats import skew
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax
plt.style.use('ggplot')
pd.options.display.max_columns = None
pd.options.display.max_rows = 600

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
# Adding 'type' columns that contains 'train' or 'test', and add empty SalePrice columns to the test part
train.insert(0, 'type', 'train')
test.insert(0,'type','test')
test['SalePrice'] = 0.0

# merging the two dataframes
merged = pd.concat([train,test],axis=0).reset_index(drop=True)
merged['SalePrice'] = merged['SalePrice'].astype('float')

# Data cleaning
import Dprocessv5
train = Dprocessv5.dataProcess(merged);

# %%
# numerical and categorical features + EXCLUDED FIRST
excl_features = merged[['Id','type','SalePrice']].columns
cat_features = merged.select_dtypes(include = ["object"]).columns.drop('type')
num_features = merged.select_dtypes(exclude = ["object"]).columns.drop(['Id','SalePrice'])

mergedNum = merged[num_features]
mergedCat = merged[cat_features]
mergedExc = merged[excl_features]

mergedNAtotal = merged.isnull().sum().sort_values(ascending=False)

print("NAs for numerical features in merged : " + str(mergedNum.isnull().values.sum()))

if mergedNum.isnull().values.sum() != 0:
    mergedNum = mergedNum.fillna(mergedNum.median())
    print("Remaining NAs for numerical features in merged : " + str(mergedNum.isnull().values.sum()))
# Out:
# NAs for numerical features in merged : 0

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerics2 = []
for i in merged.columns:
    if merged[i].dtype in numeric_dtypes: 
        numerics2.append(i)

skew_features = merged[numerics2].apply(lambda x: skew(x)).sort_values(ascending=False)
skews = pd.DataFrame({'skew':skew_features})

# %%
high_skew = skew_features[skew_features > 0.5]
high_skew = high_skew
skew_index = high_skew.index

for i in skew_index:
    if i != 'SalePrice':
        merged[i]= boxcox1p(merged[i], boxcox_normmax(merged[i]+1))

        
skew_features2 = merged[numerics2].apply(lambda x: skew(x)).sort_values(ascending=False)
skews2 = pd.DataFrame({'skew':skew_features2})

# %%
# Create dummy features for categorical values via one-hot encoding

print("Remaining NAs for categorical features in merged : " + str(mergedCat.isnull().values.sum()))

print("NAs for categorical features in merged : " + str(mergedCat.isnull().values.sum()))

mergedCat = pd.get_dummies(mergedCat)
# Out:
# Remaining NAs for categorical features in merged : 0
# NAs for categorical features in merged : 0

# %%
# rejoin excluded, categorical and numerical features
merged = pd.concat([mergedExc,mergedNum, mergedCat], axis = 1)

print("New number of features : " + str(merged.shape[1]))
# Out:
# New number of features : 335

# %%
merged.shape
# Out:
# (2915, 335)

# %%
train = merged[merged['type'] == 'train'].copy()
train.drop(columns=['Id','type'],inplace=True)
test = merged[merged['type'] == 'test'].copy()
test.drop(columns=['type','SalePrice'],inplace=True)

# %%
# taking the log of the saleprice

train['SalePrice'] = np.log(train['SalePrice'])
train['SalePrice'].describe()
# Out:
# count    1456.000000
# mean       12.022909
# std         0.398649
# min        10.460242
# 25%        11.774520
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import sklearn.model_selection as ms
from scipy.stats import norm
from scipy.stats import skew
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.ensemble import (GradientBoostingRegressor , RandomForestRegressor,
                              BaggingRegressor,ExtraTreesRegressor,AdaBoostRegressor)
from scipy import stats
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
y = train.SalePrice

# %% [markdown]
# ## Defining the train/test split (80/20)

# %%
house_features = train.drop('SalePrice',axis = 1)
prices = train['SalePrice']

x_train, x_test, y_train, y_test = ms.train_test_split(house_features, prices, 
                                                       test_size=0.2, random_state=111)

# %% [markdown]
# ## Ridge

# %%
# 981 
# 0.12077
# R2: 0.9420
# trainRMSE: 0.096945
# testRMSE: 0.101837

ridcv = RidgeCV(alphas=np.linspace(1e-5,30,10000), normalize=False, scoring=None)

ridcv.fit(x_train,y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=ridcv.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=ridcv.predict(x_test)))

print('The best alpha is: {:.2%}\n\nThe ridge intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    ridcv.alpha_,ridcv.intercept_, pd.Series(ridcv.coef_, index=x_train.columns), ridcv.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(ridcv.predict(test.drop(columns='Id')))}
#             ).to_csv('ridcv {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# The best alpha is: 2024.30%
#
# The ridge intercept is: 5.31
#
# LotFrontage              0.000490
# LotArea                  0.000002
# OverallQual              0.050000
# OverallCond              0.040034
# YearBuilt                0.002033
# YearRemodAdd             0.000680
# MasVnrArea               0.000026
# BsmtFinSF1               0.000058
# BsmtFinSF2               0.000044
# BsmtUnfSF               -0.000011
# TotalBsmtSF              0.000091
# 1stFlrSF                 0.000106
# 2ndFlrSF                 0.000094
# LowQualFinSF            -0.000033
# GrLivArea                0.000166
# BsmtFullBath             0.020115
# BsmtHalfBath             0.005169
# FullBath                 0.020434
# HalfBath                 0.028653
# BedroomAbvGr            -0.004379
# KitchenAbvGr            -0.013573
# TotRmsAbvGrd            -0.000793
# Fireplaces               0.003851
# GarageYrBlt             -0.000037
# GarageCars               0.023184
# GarageArea               0.000080
# WoodDeckSF               0.000088
# OpenPorchSF              0.000069
# EnclosedPorch            0.000116
# 3SsnPorch                0.000171
# ScreenPorch              0.000228
# PoolArea                 0.000187
# MiscVal                  0.000003
# MSSubClass_120           0.014901
# MSSubClass_150           0.000000
# MSSubClass_160          -0.040706
# MSSubClass_180          -0.001368
# MSSubClass_190          -0.002022
# MSSubClass_20            0.005353
# MSSubClass_30           -0.033794
# MSSubClass_40            0.001199
# MSSubClass_45            0.007429
# MSSubClass_50            0.007132
# MSSubClass_60            0.007329
# MSSubClass_70            0.032714
# MSSubClass_75           -0.000771
# MSSubClass_80            0.003607
# MSSubClass_85            0.001095
# MSSubClass_90           -0.002101
# MSZoning_C (all)        -0.067571
# MSZoning_FV              0.037909
# MSZoning_RH              0.005640
# MSZoning_RL              0.041048
# MSZoning_RM             -0.017026
# Street_Grvl             -0.010795
# Street_Pave              0.010795
# Alley_Grvl              -0.004160
# Alley_None              -0.002963
# Alley_Pave               0.007124
# LotShape_IR1            -0.000663
# LotShape_IR2             0.003187
# LotShape_IR3            -0.000007
# LotShape_Reg            -0.002517
# LandContour_Bnk         -0.004102
# LandContour_HLS          0.007257
# LandContour_Low         -0.014121
# LandContour_Lvl          0.010966
# Utilities_AllPub         0.005182
# Utilities_NoSeWa        -0.005182
# LotConfig_Corner         0.001993
# LotConfig_CulDSac        0.024169
# LotConfig_FR2           -0.015963
# LotConfig_FR3            0.000780
# LotConfig_Inside        -0.010979
# LandSlope_Gtl            0.011276
# LandSlope_Mod            0.012147
# LandSlope_Sev           -0.023423
# Neighborhood_Blmngtn    -0.012856
# Neighborhood_Blueste     0.000589
# Neighborhood_BrDale     -0.004696
# Neighborhood_BrkSide     0.022869
# Neighborhood_ClearCr     0.020108
# Neighborhood_CollgCr    -0.010374
# Neighborhood_Crawfor     0.071613
# Neighborhood_Edwards    -0.029564
# Neighborhood_Gilbert    -0.010290
# Neighborhood_IDOTRR     -0.012382
# Neighborhood_MeadowV    -0.041287
# Neighborhood_Mitchel    -0.028078
# Neighborhood_NAmes      -0.015587
# Neighborhood_NPkVill     0.004795
# Neighborhood_NWAmes     -0.017605
# Neighborhood_NoRidge     0.007784
# Neighborhood_NridgHt     0.025811
# Neighborhood_OldTown    -0.014583
# Neighborhood_SWISU      -0.005684
# Neighborhood_Sawyer     -0.010361
# Neighborhood_SawyerW    -0.004725
# Neighborhood_Somerst     0.030640
# Neighborhood_StoneBr     0.039602
# Neighborhood_Timber     -0.012382
# Neighborhood_Veenker     0.006643
# Condition1_Artery       -0.025329
# Condition1_Feedr        -0.003639
# Condition1_Norm          0.042602
# Condition1_PosA         -0.004875
# Condition1_PosN          0.004308
# Condition1_RRAe         -0.019860
# Condition1_RRAn          0.009576
# Condition1_RRNe         -0.003931
# Condition1_RRNn          0.001148
# Condition2_Artery       -0.002936
# Condition2_Feedr         0.002234
# Condition2_Norm         -0.000106
# Condition2_PosA          0.006529
# Condition2_PosN          0.000000
# Condition2_RRAe          0.000000
# Condition2_RRAn         -0.004120
# Condition2_RRNn         -0.001602
# BldgType_1Fam            0.022729
# BldgType_2fmCon          0.000553
# BldgType_Duplex         -0.002101
# BldgType_Twnhs          -0.021646
# BldgType_TwnhsE          0.000465
# HouseStyle_1.5Fin       -0.000258
# HouseStyle_1.5Unf        0.012360
# HouseStyle_1Story        0.000067
# HouseStyle_2.5Fin       -0.009526
# HouseStyle_2.5Unf        0.006599
# HouseStyle_2Story       -0.015551
# HouseStyle_SFoyer       -0.003266
# HouseStyle_SLvl          0.009575
# RoofStyle_Flat          -0.003484
# RoofStyle_Gable         -0.000724
# RoofStyle_Gambrel       -0.013361
# RoofStyle_Hip            0.000325
# RoofStyle_Mansard        0.009438
# RoofStyle_Shed           0.007806
# RoofMatl_CompShg         0.008082
# RoofMatl_Membran         0.000000
# RoofMatl_Metal           0.004507
# RoofMatl_Roll           -0.002074
# RoofMatl_Tar&Grv        -0.014284
# RoofMatl_WdShake        -0.001943
# RoofMatl_WdShngl         0.005711
# Exterior1st_AsbShng      0.014774
# Exterior1st_AsphShn     -0.002190
# Exterior1st_BrkComm      0.003073
# Exterior1st_BrkFace      0.028470
# Exterior1st_CBlock      -0.004277
# Exterior1st_CemntBd     -0.000925
# Exterior1st_HdBoard     -0.013055
# Exterior1st_ImStucc      0.000000
# Exterior1st_MetalSd      0.003033
# Exterior1st_Plywood     -0.005259
# Exterior1st_Stone       -0.003083
# Exterior1st_Stucco       0.012139
# Exterior1st_VinylSd      0.000204
# Exterior1st_Wd Sdng     -0.030418
# Exterior1st_WdShing     -0.002485
# Exterior2nd_AsbShng      0.015865
# Exterior2nd_AsphShn     -0.004485
# Exterior2nd_Brk Cmn      0.008070
# Exterior2nd_BrkFace     -0.016844
# Exterior2nd_CBlock      -0.004277
# Exterior2nd_CmentBd      0.005685
# Exterior2nd_HdBoard     -0.006601
# Exterior2nd_ImStucc     -0.006653
# Exterior2nd_MetalSd      0.004176
# Exterior2nd_Other       -0.001529
# Exterior2nd_Plywood     -0.009733
# Exterior2nd_Stone       -0.001118
# Exterior2nd_Stucco      -0.005328
# Exterior2nd_VinylSd      0.002302
# Exterior2nd_Wd Sdng      0.020229
# Exterior2nd_Wd Shng      0.000241
# MasVnrType_BrkCmn       -0.012815
# MasVnrType_BrkFace      -0.009654
# MasVnrType_None          0.001037
# MasVnrType_Stone         0.021432
# ExterQual_Ex             0.017290
# ExterQual_Fa            -0.003688
# ExterQual_Gd             0.000590
# ExterQual_TA            -0.014192
# ExterCond_Ex             0.010016
# ExterCond_Fa            -0.011626
# ExterCond_Gd            -0.008658
# ExterCond_Po            -0.000137
# ExterCond_TA             0.010406
# Foundation_BrkTil       -0.006161
# Foundation_CBlock        0.000287
# Foundation_PConc         0.021968
# Foundation_Slab         -0.005246
# Foundation_Stone         0.007777
# Foundation_Wood         -0.018624
# BsmtQual_0              -0.003037
# BsmtQual_Ex              0.022715
# BsmtQual_Fa              0.002283
# BsmtQual_Gd             -0.010247
# BsmtQual_TA             -0.011713
# BsmtCond_0              -0.003037
# BsmtCond_Fa             -0.012365
# BsmtCond_Gd              0.007100
# BsmtCond_Po             -0.000665
# BsmtCond_TA              0.008968
# BsmtExposure_Av         -0.008253
# BsmtExposure_Gd          0.036664
# BsmtExposure_Mn         -0.009986
# BsmtExposure_No         -0.012904
# BsmtExposure_None       -0.005521
# BsmtFinType1_ALQ         0.005407
# BsmtFinType1_BLQ         0.010337
# BsmtFinType1_GLQ         0.009939
# BsmtFinType1_LwQ        -0.005171
# BsmtFinType1_None       -0.003037
# BsmtFinType1_Rec        -0.006821
# BsmtFinType1_Unf        -0.010654
# BsmtFinType2_ALQ         0.012932
# BsmtFinType2_BLQ        -0.015132
# BsmtFinType2_GLQ         0.006790
# BsmtFinType2_LwQ        -0.002599
# BsmtFinType2_None       -0.005656
# BsmtFinType2_Rec        -0.001696
# BsmtFinType2_Unf         0.005360
# Heating_Floor            0.000000
# Heating_GasA             0.010291
# Heating_GasW             0.015307
# Heating_Grav            -0.029649
# Heating_OthW            -0.002873
# Heating_Wall             0.006924
# HeatingQC_Ex             0.015670
# HeatingQC_Fa            -0.012972
# HeatingQC_Gd             0.002622
# HeatingQC_Po             0.000000
# HeatingQC_TA            -0.005321
# CentralAir_N            -0.024840
# CentralAir_Y             0.024840
# Electrical_FuseA         0.015922
# Electrical_FuseF         0.003584
# Electrical_FuseP        -0.005799
# Electrical_Mix          -0.004152
# Electrical_SBrkr        -0.009556
# KitchenQual_Ex           0.031268
# KitchenQual_Fa          -0.002235
# KitchenQual_Gd          -0.013993
# KitchenQual_None         0.000000
# KitchenQual_TA          -0.015040
# Functional_Maj1         -0.015797
# Functional_Maj2         -0.018101
# Functional_Min1         -0.000099
# Functional_Min2          0.010864
# Functional_Mod          -0.018115
# Functional_Sev           0.000000
# Functional_Typ           0.041247
# FireplaceQu_0           -0.020721
# FireplaceQu_Ex          -0.001428
# FireplaceQu_Fa          -0.004255
# FireplaceQu_Gd           0.008227
# FireplaceQu_Po           0.014975
# FireplaceQu_TA           0.003202
# GarageType_2Types       -0.009621
# GarageType_Attchd        0.012197
# GarageType_Basment      -0.011022
# GarageType_BuiltIn       0.011665
# GarageType_CarPort      -0.008580
# GarageType_Detchd        0.012208
# GarageType_None         -0.006848
# GarageFinish_Fin         0.000756
# GarageFinish_None       -0.006848
# GarageFinish_RFn        -0.000135
# GarageFinish_Unf         0.006227
# GarageQual_0            -0.006848
# GarageQual_Ex            0.005532
# GarageQual_Fa           -0.004806
# GarageQual_Gd            0.015616
# GarageQual_Po           -0.005084
# GarageQual_TA           -0.004410
# GarageCond_0            -0.006848
# GarageCond_Ex            0.005532
# GarageCond_Fa           -0.019579
# GarageCond_Gd            0.008606
# GarageCond_Po            0.007443
# GarageCond_TA            0.004846
# PavedDrive_N            -0.002837
# PavedDrive_P            -0.003131
# PavedDrive_Y             0.005968
# PoolQC_Ex               -0.011279
# PoolQC_Fa               -0.001180
# PoolQC_Gd                0.009371
# PoolQC_None              0.003087
# Fence_GdPrv             -0.003892
# Fence_GdWo              -0.013826
# Fence_MnPrv              0.003174
# Fence_MnWw               0.009177
# Fence_None               0.005368
# MiscFeature_Gar2         0.000173
# MiscFeature_None         0.004473
# MiscFeature_Othr         0.002983
# MiscFeature_Shed        -0.007629
# MiscFeature_TenC         0.000000
# MoSold_1                -0.004718
# MoSold_10                0.004704
# MoSold_11               -0.010539
# MoSold_12                0.008654
# MoSold_2                -0.007154
# MoSold_3                -0.007780
# MoSold_4                -0.004111
# MoSold_5                 0.014577
# MoSold_6                 0.010160
# MoSold_7                 0.005408
# MoSold_8                -0.001149
# MoSold_9                -0.008051
# YrSold_2006              0.010326
# YrSold_2007             -0.003446
# YrSold_2008              0.000626
# YrSold_2009             -0.010950
# YrSold_2010              0.003444
# SaleType_COD            -0.008693
# SaleType_CWD             0.009568
# SaleType_Con             0.006558
# SaleType_ConLD           0.008518
# SaleType_ConLI          -0.016332
# SaleType_ConLw          -0.002735
# SaleType_New             0.025422
# SaleType_Oth             0.007479
# SaleType_WD             -0.029783
# SaleCondition_Abnorml   -0.037200
# SaleCondition_AdjLand    0.008901
# SaleCondition_Alloca     0.005686
# SaleCondition_Family    -0.024200
# SaleCondition_Normal     0.030409
# SaleCondition_Partial    0.016404
# dtype: float64
#
# The model score is 94.19%
#
# Train RMSE: 9.45%
#
# Test RMSE: 12.27%
#
# Diff in RMSE: 3%

# %%
#  
# 
# R2: 
# trainRMSE: 
# testRMSE: 

ridge = Ridge()
parameters = {'alpha':np.linspace(20,25,1000)}
ridgegs = ms.GridSearchCV(ridge, parameters, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
ridgegs.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=ridgegs.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=ridgegs.predict(x_test)))

ridgegs.best_params_


# print('The best parameters are: {}\n\nThe ridge intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
#     ridgegs.alpha_,ridgegs.intercept_, pd.Series(ridgegs.coef_, index=x_train.columns), ridgegs.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))
# Out:
# {'alpha': 20.865865865865867}

# %%
ridcv = RidgeCV(alphas=[20.865865865865867], normalize=False, scoring=None)

ridcv.fit(x_train,y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=ridcv.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=ridcv.predict(x_test)))

print('The best alpha is: {:.2%}\n\nThe ridge intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    ridcv.alpha_,ridcv.intercept_, pd.Series(ridcv.coef_, index=x_train.columns), ridcv.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(ridcv.predict(test.drop(columns='Id')))}
#             ).to_csv('ridcv {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# The best alpha is: 20.865866
#
# The ridge intercept is: 5.30
#
# LotFrontage              0.000490
# LotArea                  0.000002
# OverallQual              0.050111
# OverallCond              0.040105
# YearBuilt                0.002037
# YearRemodAdd             0.000682
# MasVnrArea               0.000027
# BsmtFinSF1               0.000058
# BsmtFinSF2               0.000044
# BsmtUnfSF               -0.000011
# TotalBsmtSF              0.000092
# 1stFlrSF                 0.000106
# 2ndFlrSF                 0.000094
# LowQualFinSF            -0.000034
# GrLivArea                0.000166
# BsmtFullBath             0.020023
# BsmtHalfBath             0.005044
# FullBath                 0.020205
# HalfBath                 0.028476
# BedroomAbvGr            -0.004439
# KitchenAbvGr            -0.013456
# TotRmsAbvGrd            -0.000776
# Fireplaces               0.004017
# GarageYrBlt             -0.000035
# GarageCars               0.023098
# GarageArea               0.000080
# WoodDeckSF               0.000088
# OpenPorchSF              0.000069
# EnclosedPorch            0.000117
# 3SsnPorch                0.000171
# ScreenPorch              0.000228
# PoolArea                 0.000186
# MiscVal                  0.000003
# MSSubClass_120           0.014869
# MSSubClass_150           0.000000
# MSSubClass_160          -0.040326
# MSSubClass_180          -0.001376
# MSSubClass_190          -0.002012
# MSSubClass_20            0.005350
# MSSubClass_30           -0.033446
# MSSubClass_40            0.001186
# MSSubClass_45            0.007398
# MSSubClass_50            0.007057
# MSSubClass_60            0.007156
# MSSubClass_70            0.032355
# MSSubClass_75           -0.000793
# MSSubClass_80            0.003664
# MSSubClass_85            0.001061
# MSSubClass_90           -0.002144
# MSZoning_C (all)        -0.066132
# MSZoning_FV              0.037380
# MSZoning_RH              0.005395
# MSZoning_RL              0.040694
# MSZoning_RM             -0.017337
# Street_Grvl             -0.010606
# Street_Pave              0.010606
# Alley_Grvl              -0.004143
# Alley_None              -0.002888
# Alley_Pave               0.007030
# LotShape_IR1            -0.000588
# LotShape_IR2             0.003223
# LotShape_IR3            -0.000095
# LotShape_Reg            -0.002539
# LandContour_Bnk         -0.004048
# LandContour_HLS          0.007153
# LandContour_Low         -0.013934
# LandContour_Lvl          0.010829
# Utilities_AllPub         0.005048
# Utilities_NoSeWa        -0.005048
# LotConfig_Corner         0.001927
# LotConfig_CulDSac        0.023949
# LotConfig_FR2           -0.015724
# LotConfig_FR3            0.000780
# LotConfig_Inside        -0.010932
# LandSlope_Gtl            0.011105
# LandSlope_Mod            0.011880
# LandSlope_Sev           -0.022985
# Neighborhood_Blmngtn    -0.012578
# Neighborhood_Blueste     0.000544
# Neighborhood_BrDale     -0.004750
# Neighborhood_BrkSide     0.022739
# Neighborhood_ClearCr     0.019763
# Neighborhood_CollgCr    -0.010295
# Neighborhood_Crawfor     0.070811
# Neighborhood_Edwards    -0.029230
# Neighborhood_Gilbert    -0.010167
# Neighborhood_IDOTRR     -0.012412
# Neighborhood_MeadowV    -0.040502
# Neighborhood_Mitchel    -0.027721
# Neighborhood_NAmes      -0.015338
# Neighborhood_NPkVill     0.004690
# Neighborhood_NWAmes     -0.017363
# Neighborhood_NoRidge     0.007543
# Neighborhood_NridgHt     0.025514
# Neighborhood_OldTown    -0.014493
# Neighborhood_SWISU      -0.005505
# Neighborhood_Sawyer     -0.010186
# Neighborhood_SawyerW    -0.004699
# Neighborhood_Somerst     0.030424
# Neighborhood_StoneBr     0.038913
# Neighborhood_Timber     -0.012242
# Neighborhood_Veenker     0.006539
# Condition1_Artery       -0.025140
# Condition1_Feedr        -0.003716
# Condition1_Norm          0.042402
# Condition1_PosA         -0.004867
# Condition1_PosN          0.004162
# Condition1_RRAe         -0.019496
# Condition1_RRAn          0.009395
# Condition1_RRNe         -0.003837
# Condition1_RRNn          0.001096
# Condition2_Artery       -0.002875
# Condition2_Feedr         0.002188
# Condition2_Norm         -0.000063
# Condition2_PosA          0.006335
# Condition2_PosN          0.000000
# Condition2_RRAe          0.000000
# Condition2_RRAn         -0.004006
# Condition2_RRNn         -0.001579
# BldgType_1Fam            0.022704
# BldgType_2fmCon          0.000500
# BldgType_Duplex         -0.002144
# BldgType_Twnhs          -0.021520
# BldgType_TwnhsE          0.000460
# HouseStyle_1.5Fin       -0.000157
# HouseStyle_1.5Unf        0.012153
# HouseStyle_1Story       -0.000012
# HouseStyle_2.5Fin       -0.009281
# HouseStyle_2.5Unf        0.006359
# HouseStyle_2Story       -0.015327
# HouseStyle_SFoyer       -0.003235
# HouseStyle_SLvl          0.009500
# RoofStyle_Flat          -0.003440
# RoofStyle_Gable         -0.000648
# RoofStyle_Gambrel       -0.013056
# RoofStyle_Hip            0.000376
# RoofStyle_Mansard        0.009209
# RoofStyle_Shed           0.007559
# RoofMatl_CompShg         0.007952
# RoofMatl_Membran         0.000000
# RoofMatl_Metal           0.004372
# RoofMatl_Roll           -0.002005
# RoofMatl_Tar&Grv        -0.013963
# RoofMatl_WdShake        -0.001934
# RoofMatl_WdShngl         0.005578
# Exterior1st_AsbShng      0.014509
# Exterior1st_AsphShn     -0.002129
# Exterior1st_BrkComm      0.002965
# Exterior1st_BrkFace      0.028092
# Exterior1st_CBlock      -0.004156
# Exterior1st_CemntBd     -0.000877
# Exterior1st_HdBoard     -0.012947
# Exterior1st_ImStucc      0.000000
# Exterior1st_MetalSd      0.003068
# Exterior1st_Plywood     -0.005269
# Exterior1st_Stone       -0.003002
# Exterior1st_Stucco       0.011898
# Exterior1st_VinylSd      0.000246
# Exterior1st_Wd Sdng     -0.029990
# Exterior1st_WdShing     -0.002407
# Exterior2nd_AsbShng      0.015621
# Exterior2nd_AsphShn     -0.004344
# Exterior2nd_Brk Cmn      0.007838
# Exterior2nd_BrkFace     -0.016436
# Exterior2nd_CBlock      -0.004156
# Exterior2nd_CmentBd      0.005525
# Exterior2nd_HdBoard     -0.006667
# Exterior2nd_ImStucc     -0.006569
# Exterior2nd_MetalSd      0.004146
# Exterior2nd_Other       -0.001459
# Exterior2nd_Plywood     -0.009679
# Exterior2nd_Stone       -0.000974
# Exterior2nd_Stucco      -0.005120
# Exterior2nd_VinylSd      0.002203
# Exterior2nd_Wd Sdng      0.019815
# Exterior2nd_Wd Shng      0.000255
# MasVnrType_BrkCmn       -0.012597
# MasVnrType_BrkFace      -0.009735
# MasVnrType_None          0.001079
# MasVnrType_Stone         0.021252
# ExterQual_Ex             0.017263
# ExterQual_Fa            -0.003712
# ExterQual_Gd             0.000600
# ExterQual_TA            -0.014152
# ExterCond_Ex             0.009737
# ExterCond_Fa            -0.011422
# ExterCond_Gd            -0.008595
# ExterCond_Po            -0.000151
# ExterCond_TA             0.010431
# Foundation_BrkTil       -0.006145
# Foundation_CBlock        0.000125
# Foundation_PConc         0.021782
# Foundation_Slab         -0.005158
# Foundation_Stone         0.007573
# Foundation_Wood         -0.018177
# BsmtQual_0              -0.002977
# BsmtQual_Ex              0.022648
# BsmtQual_Fa              0.002248
# BsmtQual_Gd             -0.010215
# BsmtQual_TA             -0.011705
# BsmtCond_0              -0.002977
# BsmtCond_Fa             -0.012267
# BsmtCond_Gd              0.007027
# BsmtCond_Po             -0.000712
# BsmtCond_TA              0.008929
# BsmtExposure_Av         -0.008213
# BsmtExposure_Gd          0.036374
# BsmtExposure_Mn         -0.009912
# BsmtExposure_No         -0.012853
# BsmtExposure_None       -0.005395
# BsmtFinType1_ALQ         0.005331
# BsmtFinType1_BLQ         0.010275
# BsmtFinType1_GLQ         0.009897
# BsmtFinType1_LwQ        -0.005078
# BsmtFinType1_None       -0.002977
# BsmtFinType1_Rec        -0.006823
# BsmtFinType1_Unf        -0.010625
# BsmtFinType2_ALQ         0.012728
# BsmtFinType2_BLQ        -0.014932
# BsmtFinType2_GLQ         0.006618
# BsmtFinType2_LwQ        -0.002574
# BsmtFinType2_None       -0.005551
# BsmtFinType2_Rec        -0.001676
# BsmtFinType2_Unf         0.005387
# Heating_Floor            0.000000
# Heating_GasA             0.010114
# Heating_GasW             0.014928
# Heating_Grav            -0.028959
# Heating_OthW            -0.002797
# Heating_Wall             0.006714
# HeatingQC_Ex             0.015633
# HeatingQC_Fa            -0.012856
# HeatingQC_Gd             0.002607
# HeatingQC_Po             0.000000
# HeatingQC_TA            -0.005384
# CentralAir_N            -0.024714
# CentralAir_Y             0.024714
# Electrical_FuseA         0.015780
# Electrical_FuseF         0.003502
# Electrical_FuseP        -0.005656
# Electrical_Mix          -0.004060
# Electrical_SBrkr        -0.009567
# KitchenQual_Ex           0.031053
# KitchenQual_Fa          -0.002165
# KitchenQual_Gd          -0.013896
# KitchenQual_None         0.000000
# KitchenQual_TA          -0.014992
# Functional_Maj1         -0.015719
# Functional_Maj2         -0.017661
# Functional_Min1         -0.000309
# Functional_Min2          0.010616
# Functional_Mod          -0.017814
# Functional_Sev           0.000000
# Functional_Typ           0.040887
# FireplaceQu_0           -0.020588
# FireplaceQu_Ex          -0.001361
# FireplaceQu_Fa          -0.004157
# FireplaceQu_Gd           0.008277
# FireplaceQu_Po           0.014715
# FireplaceQu_TA           0.003115
# GarageType_2Types       -0.009395
# GarageType_Attchd        0.012069
# GarageType_Basment      -0.010838
# GarageType_BuiltIn       0.011526
# GarageType_CarPort      -0.008508
# GarageType_Detchd        0.012006
# GarageType_None         -0.006861
# GarageFinish_Fin         0.000793
# GarageFinish_None       -0.006861
# GarageFinish_RFn        -0.000121
# GarageFinish_Unf         0.006188
# GarageQual_0            -0.006861
# GarageQual_Ex            0.005380
# GarageQual_Fa           -0.004626
# GarageQual_Gd            0.015383
# GarageQual_Po           -0.004933
# GarageQual_TA           -0.004344
# GarageCond_0            -0.006861
# GarageCond_Ex            0.005380
# GarageCond_Fa           -0.019167
# GarageCond_Gd            0.008478
# GarageCond_Po            0.007218
# GarageCond_TA            0.004952
# PavedDrive_N            -0.002888
# PavedDrive_P            -0.003065
# PavedDrive_Y             0.005953
# PoolQC_Ex               -0.011032
# PoolQC_Fa               -0.001135
# PoolQC_Gd                0.009154
# PoolQC_None              0.003013
# Fence_GdPrv             -0.003840
# Fence_GdWo              -0.013667
# Fence_MnPrv              0.003188
# Fence_MnWw               0.008940
# Fence_None               0.005379
# MiscFeature_Gar2         0.000177
# MiscFeature_None         0.004509
# MiscFeature_Othr         0.002900
# MiscFeature_Shed        -0.007586
# MiscFeature_TenC         0.000000
# MoSold_1                -0.004670
# MoSold_10                0.004682
# MoSold_11               -0.010528
# MoSold_12                0.008605
# MoSold_2                -0.007083
# MoSold_3                -0.007775
# MoSold_4                -0.004166
# MoSold_5                 0.014483
# MoSold_6                 0.010133
# MoSold_7                 0.005424
# MoSold_8                -0.001117
# MoSold_9                -0.007989
# YrSold_2006              0.010305
# YrSold_2007             -0.003395
# YrSold_2008              0.000642
# YrSold_2009             -0.010957
# YrSold_2010              0.003405
# SaleType_COD            -0.008610
# SaleType_CWD             0.009374
# SaleType_Con             0.006424
# SaleType_ConLD           0.008207
# SaleType_ConLI          -0.015910
# SaleType_ConLw          -0.002641
# SaleType_New             0.025349
# SaleType_Oth             0.007308
# SaleType_WD             -0.029502
# SaleCondition_Abnorml   -0.037090
# SaleCondition_AdjLand    0.008619
# SaleCondition_Alloca     0.005529
# SaleCondition_Family    -0.023869
# SaleCondition_Normal     0.030260
# SaleCondition_Partial    0.016551
# dtype: float64
#
# The model score is 0.9418
#
# Train RMSE: 0.094632
#
# Test RMSE: 0.122686
#
# Diff in RMSE: 0.028

# %% [markdown]
# ## Elastic-net

# %%
# 917
# 0.11994
# R2: 0.9359
# trainRMSE: 0.101935
# testRMSE: 0.100320
# diff: -0.002

enet = ElasticNetCV(l1_ratio=np.linspace(0.01,1,100), alphas=np.linspace(1e-5,20,1000), max_iter=1000, normalize=False, cv=10, n_jobs=-1)

enet.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=enet.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=enet.predict(x_test)))

print('The best alpha is: {:.2%}\n\nThe elastic-net intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    enet.alpha_,enet.intercept_, pd.Series(enet.coef_, index=x_train.columns), enet.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(enet.predict(test.drop(columns='Id')))}
#             ).to_csv('enet {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# The best alpha is: 0.020030
#
# The elastic-net intercept is: 4.94
#
# LotFrontage              0.000495
# LotArea                  0.000002
# OverallQual              0.052813
# OverallCond              0.041749
# YearBuilt                0.002131
# YearRemodAdd             0.000700
# MasVnrArea               0.000030
# BsmtFinSF1               0.000127
# BsmtFinSF2               0.000109
# BsmtUnfSF                0.000054
# TotalBsmtSF              0.000036
# 1stFlrSF                 0.000232
# 2ndFlrSF                 0.000227
# LowQualFinSF             0.000083
# GrLivArea                0.000036
# BsmtFullBath             0.017955
# BsmtHalfBath             0.000580
# FullBath                 0.015178
# HalfBath                 0.024915
# BedroomAbvGr            -0.004940
# KitchenAbvGr            -0.012071
# TotRmsAbvGrd            -0.000705
# Fireplaces               0.005884
# GarageYrBlt              0.000037
# GarageCars               0.022167
# GarageArea               0.000086
# WoodDeckSF               0.000089
# OpenPorchSF              0.000079
# EnclosedPorch            0.000119
# 3SsnPorch                0.000174
# ScreenPorch              0.000231
# PoolArea                 0.000162
# MiscVal                  0.000002
# MSSubClass_120           0.011898
# MSSubClass_150           0.000000
# MSSubClass_160          -0.036813
# MSSubClass_180          -0.000000
# MSSubClass_190          -0.000000
# MSSubClass_20            0.000000
# MSSubClass_30           -0.030681
# MSSubClass_40            0.000000
# MSSubClass_45            0.001133
# MSSubClass_50            0.004644
# MSSubClass_60            0.000000
# MSSubClass_70            0.024817
# MSSubClass_75           -0.000000
# MSSubClass_80            0.001200
# MSSubClass_85           -0.000000
# MSSubClass_90           -0.002005
# MSZoning_C (all)        -0.055276
# MSZoning_FV              0.033393
# MSZoning_RH              0.000000
# MSZoning_RL              0.037685
# MSZoning_RM             -0.019895
# Street_Grvl             -0.003535
# Street_Pave              0.003535
# Alley_Grvl              -0.000140
# Alley_None              -0.000000
# Alley_Pave               0.002900
# LotShape_IR1             0.000000
# LotShape_IR2             0.000030
# LotShape_IR3            -0.000000
# LotShape_Reg            -0.002749
# LandContour_Bnk         -0.001171
# LandContour_HLS          0.001775
# LandContour_Low         -0.008624
# LandContour_Lvl          0.008020
# Utilities_AllPub         0.000000
# Utilities_NoSeWa        -0.000000
# LotConfig_Corner         0.000000
# LotConfig_CulDSac        0.021196
# LotConfig_FR2           -0.009311
# LotConfig_FR3            0.000000
# LotConfig_Inside        -0.010009
# LandSlope_Gtl            0.003771
# LandSlope_Mod            0.002089
# LandSlope_Sev           -0.015961
# Neighborhood_Blmngtn    -0.003219
# Neighborhood_Blueste    -0.000000
# Neighborhood_BrDale     -0.000000
# Neighborhood_BrkSide     0.022841
# Neighborhood_ClearCr     0.013703
# Neighborhood_CollgCr    -0.006007
# Neighborhood_Crawfor     0.066625
# Neighborhood_Edwards    -0.022146
# Neighborhood_Gilbert    -0.003069
# Neighborhood_IDOTRR     -0.007038
# Neighborhood_MeadowV    -0.029790
# Neighborhood_Mitchel    -0.021468
# Neighborhood_NAmes      -0.007810
# Neighborhood_NPkVill     0.000000
# Neighborhood_NWAmes     -0.011052
# Neighborhood_NoRidge     0.002040
# Neighborhood_NridgHt     0.021847
# Neighborhood_OldTown    -0.008693
# Neighborhood_SWISU      -0.000000
# Neighborhood_Sawyer     -0.003647
# Neighborhood_SawyerW    -0.000273
# Neighborhood_Somerst     0.028657
# Neighborhood_StoneBr     0.032210
# Neighborhood_Timber     -0.005773
# Neighborhood_Veenker     0.000096
# Condition1_Artery       -0.020031
# Condition1_Feedr        -0.000579
# Condition1_Norm          0.042273
# Condition1_PosA         -0.000000
# Condition1_PosN          0.000000
# Condition1_RRAe         -0.011373
# Condition1_RRAn          0.004040
# Condition1_RRNe         -0.000000
# Condition1_RRNn          0.000000
# Condition2_Artery       -0.000000
# Condition2_Feedr         0.000000
# Condition2_Norm         -0.000000
# Condition2_PosA          0.000000
# Condition2_PosN          0.000000
# Condition2_RRAe          0.000000
# Condition2_RRAn         -0.000000
# Condition2_RRNn         -0.000000
# BldgType_1Fam            0.024814
# BldgType_2fmCon         -0.000000
# BldgType_Duplex         -0.002005
# BldgType_Twnhs          -0.018176
# BldgType_TwnhsE          0.000000
# HouseStyle_1.5Fin        0.000000
# HouseStyle_1.5Unf        0.005644
# HouseStyle_1Story       -0.000000
# HouseStyle_2.5Fin       -0.000533
# HouseStyle_2.5Unf        0.000000
# HouseStyle_2Story       -0.009887
# HouseStyle_SFoyer       -0.000000
# HouseStyle_SLvl          0.006858
# RoofStyle_Flat          -0.000000
# RoofStyle_Gable         -0.000000
# RoofStyle_Gambrel       -0.004600
# RoofStyle_Hip            0.000000
# RoofStyle_Mansard        0.000197
# RoofStyle_Shed           0.000000
# RoofMatl_CompShg         0.000333
# RoofMatl_Membran         0.000000
# RoofMatl_Metal           0.000000
# RoofMatl_Roll           -0.000000
# RoofMatl_Tar&Grv        -0.005157
# RoofMatl_WdShake        -0.000000
# RoofMatl_WdShngl         0.000000
# Exterior1st_AsbShng      0.007095
# Exterior1st_AsphShn     -0.000000
# Exterior1st_BrkComm      0.000000
# Exterior1st_BrkFace      0.022706
# Exterior1st_CBlock      -0.000000
# Exterior1st_CemntBd      0.000000
# Exterior1st_HdBoard     -0.012194
# Exterior1st_ImStucc      0.000000
# Exterior1st_MetalSd      0.002585
# Exterior1st_Plywood     -0.004188
# Exterior1st_Stone       -0.000000
# Exterior1st_Stucco       0.003780
# Exterior1st_VinylSd      0.000000
# Exterior1st_Wd Sdng     -0.024398
# Exterior1st_WdShing     -0.000000
# Exterior2nd_AsbShng      0.008124
# Exterior2nd_AsphShn     -0.000000
# Exterior2nd_Brk Cmn      0.000000
# Exterior2nd_BrkFace     -0.006747
# Exterior2nd_CBlock      -0.000000
# Exterior2nd_CmentBd      0.000000
# Exterior2nd_HdBoard     -0.007059
# Exterior2nd_ImStucc     -0.000000
# Exterior2nd_MetalSd      0.003078
# Exterior2nd_Other       -0.000000
# Exterior2nd_Plywood     -0.008155
# Exterior2nd_Stone        0.000000
# Exterior2nd_Stucco      -0.000000
# Exterior2nd_VinylSd      0.000000
# Exterior2nd_Wd Sdng      0.011769
# Exterior2nd_Wd Shng      0.000000
# MasVnrType_BrkCmn       -0.006011
# MasVnrType_BrkFace      -0.011697
# MasVnrType_None          0.000341
# MasVnrType_Stone         0.017367
# ExterQual_Ex             0.015779
# ExterQual_Fa            -0.000000
# ExterQual_Gd             0.000000
# ExterQual_TA            -0.012597
# ExterCond_Ex             0.000000
# ExterCond_Fa            -0.004765
# ExterCond_Gd            -0.005739
# ExterCond_Po            -0.000000
# ExterCond_TA             0.011235
# Foundation_BrkTil       -0.001227
# Foundation_CBlock       -0.000000
# Foundation_PConc         0.021797
# Foundation_Slab         -0.000000
# Foundation_Stone         0.000202
# Foundation_Wood         -0.007950
# BsmtQual_0              -0.000000
# BsmtQual_Ex              0.023750
# BsmtQual_Fa              0.000000
# BsmtQual_Gd             -0.006648
# BsmtQual_TA             -0.008458
# BsmtCond_0              -0.000000
# BsmtCond_Fa             -0.008296
# BsmtCond_Gd              0.000747
# BsmtCond_Po             -0.000000
# BsmtCond_TA              0.005545
# BsmtExposure_Av         -0.000868
# BsmtExposure_Gd          0.036846
# BsmtExposure_Mn         -0.001766
# BsmtExposure_No         -0.005294
# BsmtExposure_None       -0.000000
# BsmtFinType1_ALQ         0.003130
# BsmtFinType1_BLQ         0.008883
# BsmtFinType1_GLQ         0.007832
# BsmtFinType1_LwQ        -0.000000
# BsmtFinType1_None       -0.000000
# BsmtFinType1_Rec        -0.005385
# BsmtFinType1_Unf        -0.008188
# BsmtFinType2_ALQ         0.006879
# BsmtFinType2_BLQ        -0.009401
# BsmtFinType2_GLQ         0.000000
# BsmtFinType2_LwQ        -0.000000
# BsmtFinType2_None       -0.000000
# BsmtFinType2_Rec        -0.000000
# BsmtFinType2_Unf         0.004439
# Heating_Floor            0.000000
# Heating_GasA             0.002433
# Heating_GasW             0.004792
# Heating_Grav            -0.019804
# Heating_OthW            -0.000000
# Heating_Wall             0.000000
# HeatingQC_Ex             0.014889
# HeatingQC_Fa            -0.009424
# HeatingQC_Gd             0.000858
# HeatingQC_Po             0.000000
# HeatingQC_TA            -0.006323
# CentralAir_N            -0.022806
# CentralAir_Y             0.022806
# Electrical_FuseA         0.012530
# Electrical_FuseF         0.000000
# Electrical_FuseP        -0.000000
# Electrical_Mix          -0.000000
# Electrical_SBrkr        -0.008341
# KitchenQual_Ex           0.030900
# KitchenQual_Fa          -0.000000
# KitchenQual_Gd          -0.008932
# KitchenQual_None         0.000000
# KitchenQual_TA          -0.011177
# Functional_Maj1         -0.010771
# Functional_Maj2         -0.007062
# Functional_Min1         -0.000000
# Functional_Min2          0.005128
# Functional_Mod          -0.009882
# Functional_Sev           0.000000
# Functional_Typ           0.037472
# FireplaceQu_0           -0.020356
# FireplaceQu_Ex          -0.000000
# FireplaceQu_Fa          -0.000000
# FireplaceQu_Gd           0.007492
# FireplaceQu_Po           0.006573
# FireplaceQu_TA           0.000000
# GarageType_2Types       -0.001004
# GarageType_Attchd        0.008984
# GarageType_Basment      -0.003326
# GarageType_BuiltIn       0.007144
# GarageType_CarPort      -0.002825
# GarageType_Detchd        0.007097
# GarageType_None         -0.005969
# GarageFinish_Fin         0.000269
# GarageFinish_None       -0.005969
# GarageFinish_RFn        -0.000000
# GarageFinish_Unf         0.004212
# GarageQual_0            -0.005969
# GarageQual_Ex            0.000000
# GarageQual_Fa           -0.000000
# GarageQual_Gd            0.010309
# GarageQual_Po           -0.000000
# GarageQual_TA           -0.000000
# GarageCond_0            -0.005969
# GarageCond_Ex            0.000000
# GarageCond_Fa           -0.012155
# GarageCond_Gd            0.000181
# GarageCond_Po            0.000000
# GarageCond_TA            0.004924
# PavedDrive_N            -0.000780
# PavedDrive_P            -0.000000
# PavedDrive_Y             0.005191
# PoolQC_Ex               -0.001409
# PoolQC_Fa               -0.000000
# PoolQC_Gd                0.000000
# PoolQC_None              0.000000
# Fence_GdPrv             -0.001192
# Fence_GdWo              -0.009707
# Fence_MnPrv              0.000000
# Fence_MnWw               0.000000
# Fence_None               0.003594
# MiscFeature_Gar2         0.000000
# MiscFeature_None         0.001713
# MiscFeature_Othr         0.000000
# MiscFeature_Shed        -0.004877
# MiscFeature_TenC         0.000000
# MoSold_1                -0.000000
# MoSold_10                0.002457
# MoSold_11               -0.008303
# MoSold_12                0.005498
# MoSold_2                -0.002030
# MoSold_3                -0.006046
# MoSold_4                -0.002311
# MoSold_5                 0.012507
# MoSold_6                 0.009676
# MoSold_7                 0.005190
# MoSold_8                -0.000000
# MoSold_9                -0.004569
# YrSold_2006              0.009119
# YrSold_2007             -0.002296
# YrSold_2008              0.000000
# YrSold_2009             -0.011304
# YrSold_2010              0.000054
# SaleType_COD            -0.003624
# SaleType_CWD             0.000399
# SaleType_Con             0.000000
# SaleType_ConLD           0.000000
# SaleType_ConLI          -0.006502
# SaleType_ConLw          -0.000000
# SaleType_New             0.025605
# SaleType_Oth             0.000000
# SaleType_WD             -0.024746
# SaleCondition_Abnorml   -0.036520
# SaleCondition_AdjLand    0.000000
# SaleCondition_Alloca     0.000000
# SaleCondition_Family    -0.019148
# SaleCondition_Normal     0.027722
# SaleCondition_Partial    0.016728
# dtype: float64
#
# The model score is 0.9381
#
# Train RMSE: 0.097584
#
# Test RMSE: 0.122209
#
# Diff in RMSE: 0.025

# %%
# 917
# 0.11994
# R2: 0.9359
# trainRMSE: 0.101935
# testRMSE: 0.100320
# diff: -0.002

elasticnet = ElasticNet(max_iter=1000, normalize=False)
parameters = {'alpha':np.linspace(1e-5,20,1000), 'l1_ratio':np.linspace(0.01,1,100)}

elastgs = ms.GridSearchCV(elasticnet, parameters, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
elastgs.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=elastgs.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=elastgs.predict(x_test)))

elastgs.best_params_

pickle.dump(elastgs, open('elastgs', 'wb'))

# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(enet.predict(test.drop(columns='Id')))}
#             ).to_csv('enet {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-05391dc3aba0> in <module>
#      10
#      11 elastgs = ms.GridSearchCV(elasticnet, parameters, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
# ---> 12 elastgs.fit(x_train, y_train)
#      13
#      14 trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=elastgs.predict(x_train)))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# 
# 
# R2: 
# trainRMSE: 
# testRMSE: 
# diff: 

parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svc = svm.SVC(gamma="scale")
clf = GridSearchCV(svc, parameters, cv=5)
clf.fit(iris.data, iris.target)

enet = ElasticNetCV(l1_ratio=np.linspace(0.01,1,100), alphas=np.linspace(1e-5,20,1000), max_iter=1000, normalize=False, cv=10, n_jobs=-1)

enet.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=enet.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=enet.predict(x_test)))

print('The best alpha is: {:.2%}\n\nThe elastic-net intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    enet.alpha_,enet.intercept_, pd.Series(enet.coef_, index=x_train.columns), enet.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(enet.predict(test.drop(columns='Id')))}
#             ).to_csv('enet {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/macpro/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# The best alpha is: 0.020030
#
# The elastic-net intercept is: 4.94
#
# LotFrontage              0.000495
# LotArea                  0.000002
# OverallQual              0.052813
# OverallCond              0.041749
# YearBuilt                0.002131
# YearRemodAdd             0.000700
# MasVnrArea               0.000030
# BsmtFinSF1               0.000127
# BsmtFinSF2               0.000109
# BsmtUnfSF                0.000054
# TotalBsmtSF              0.000036
# 1stFlrSF                 0.000232
# 2ndFlrSF                 0.000227
# LowQualFinSF             0.000083
# GrLivArea                0.000036
# BsmtFullBath             0.017955
# BsmtHalfBath             0.000580
# FullBath                 0.015178
# HalfBath                 0.024915
# BedroomAbvGr            -0.004940
# KitchenAbvGr            -0.012071
# TotRmsAbvGrd            -0.000705
# Fireplaces               0.005884
# GarageYrBlt              0.000037
# GarageCars               0.022167
# GarageArea               0.000086
# WoodDeckSF               0.000089
# OpenPorchSF              0.000079
# EnclosedPorch            0.000119
# 3SsnPorch                0.000174
# ScreenPorch              0.000231
# PoolArea                 0.000162
# MiscVal                  0.000002
# MSSubClass_120           0.011898
# MSSubClass_150           0.000000
# MSSubClass_160          -0.036813
# MSSubClass_180          -0.000000
# MSSubClass_190          -0.000000
# MSSubClass_20            0.000000
# MSSubClass_30           -0.030681
# MSSubClass_40            0.000000
# MSSubClass_45            0.001133
# MSSubClass_50            0.004644
# MSSubClass_60            0.000000
# MSSubClass_70            0.024817
# MSSubClass_75           -0.000000
# MSSubClass_80            0.001200
# MSSubClass_85           -0.000000
# MSSubClass_90           -0.002005
# MSZoning_C (all)        -0.055276
# MSZoning_FV              0.033393
# MSZoning_RH              0.000000
# MSZoning_RL              0.037685
# MSZoning_RM             -0.019895
# Street_Grvl             -0.003535
# Street_Pave              0.003535
# Alley_Grvl              -0.000140
# Alley_None              -0.000000
# Alley_Pave               0.002900
# LotShape_IR1             0.000000
# LotShape_IR2             0.000030
# LotShape_IR3            -0.000000
# LotShape_Reg            -0.002749
# LandContour_Bnk         -0.001171
# LandContour_HLS          0.001775
# LandContour_Low         -0.008624
# LandContour_Lvl          0.008020
# Utilities_AllPub         0.000000
# Utilities_NoSeWa        -0.000000
# LotConfig_Corner         0.000000
# LotConfig_CulDSac        0.021196
# LotConfig_FR2           -0.009311
# LotConfig_FR3            0.000000
# LotConfig_Inside        -0.010009
# LandSlope_Gtl            0.003771
# LandSlope_Mod            0.002089
# LandSlope_Sev           -0.015961
# Neighborhood_Blmngtn    -0.003219
# Neighborhood_Blueste    -0.000000
# Neighborhood_BrDale     -0.000000
# Neighborhood_BrkSide     0.022841
# Neighborhood_ClearCr     0.013703
# Neighborhood_CollgCr    -0.006007
# Neighborhood_Crawfor     0.066625
# Neighborhood_Edwards    -0.022146
# Neighborhood_Gilbert    -0.003069
# Neighborhood_IDOTRR     -0.007038
# Neighborhood_MeadowV    -0.029790
# Neighborhood_Mitchel    -0.021468
# Neighborhood_NAmes      -0.007810
# Neighborhood_NPkVill     0.000000
# Neighborhood_NWAmes     -0.011052
# Neighborhood_NoRidge     0.002040
# Neighborhood_NridgHt     0.021847
# Neighborhood_OldTown    -0.008693
# Neighborhood_SWISU      -0.000000
# Neighborhood_Sawyer     -0.003647
# Neighborhood_SawyerW    -0.000273
# Neighborhood_Somerst     0.028657
# Neighborhood_StoneBr     0.032210
# Neighborhood_Timber     -0.005773
# Neighborhood_Veenker     0.000096
# Condition1_Artery       -0.020031
# Condition1_Feedr        -0.000579
# Condition1_Norm          0.042273
# Condition1_PosA         -0.000000
# Condition1_PosN          0.000000
# Condition1_RRAe         -0.011373
# Condition1_RRAn          0.004040
# Condition1_RRNe         -0.000000
# Condition1_RRNn          0.000000
# Condition2_Artery       -0.000000
# Condition2_Feedr         0.000000
# Condition2_Norm         -0.000000
# Condition2_PosA          0.000000
# Condition2_PosN          0.000000
# Condition2_RRAe          0.000000
# Condition2_RRAn         -0.000000
# Condition2_RRNn         -0.000000
# BldgType_1Fam            0.024814
# BldgType_2fmCon         -0.000000
# BldgType_Duplex         -0.002005
# BldgType_Twnhs          -0.018176
# BldgType_TwnhsE          0.000000
# HouseStyle_1.5Fin        0.000000
# HouseStyle_1.5Unf        0.005644
# HouseStyle_1Story       -0.000000
# HouseStyle_2.5Fin       -0.000533
# HouseStyle_2.5Unf        0.000000
# HouseStyle_2Story       -0.009887
# HouseStyle_SFoyer       -0.000000
# HouseStyle_SLvl          0.006858
# RoofStyle_Flat          -0.000000
# RoofStyle_Gable         -0.000000
# RoofStyle_Gambrel       -0.004600
# RoofStyle_Hip            0.000000
# RoofStyle_Mansard        0.000197
# RoofStyle_Shed           0.000000
# RoofMatl_CompShg         0.000333
# RoofMatl_Membran         0.000000
# RoofMatl_Metal           0.000000
# RoofMatl_Roll           -0.000000
# RoofMatl_Tar&Grv        -0.005157
# RoofMatl_WdShake        -0.000000
# RoofMatl_WdShngl         0.000000
# Exterior1st_AsbShng      0.007095
# Exterior1st_AsphShn     -0.000000
# Exterior1st_BrkComm      0.000000
# Exterior1st_BrkFace      0.022706
# Exterior1st_CBlock      -0.000000
# Exterior1st_CemntBd      0.000000
# Exterior1st_HdBoard     -0.012194
# Exterior1st_ImStucc      0.000000
# Exterior1st_MetalSd      0.002585
# Exterior1st_Plywood     -0.004188
# Exterior1st_Stone       -0.000000
# Exterior1st_Stucco       0.003780
# Exterior1st_VinylSd      0.000000
# Exterior1st_Wd Sdng     -0.024398
# Exterior1st_WdShing     -0.000000
# Exterior2nd_AsbShng      0.008124
# Exterior2nd_AsphShn     -0.000000
# Exterior2nd_Brk Cmn      0.000000
# Exterior2nd_BrkFace     -0.006747
# Exterior2nd_CBlock      -0.000000
# Exterior2nd_CmentBd      0.000000
# Exterior2nd_HdBoard     -0.007059
# Exterior2nd_ImStucc     -0.000000
# Exterior2nd_MetalSd      0.003078
# Exterior2nd_Other       -0.000000
# Exterior2nd_Plywood     -0.008155
# Exterior2nd_Stone        0.000000
# Exterior2nd_Stucco      -0.000000
# Exterior2nd_VinylSd      0.000000
# Exterior2nd_Wd Sdng      0.011769
# Exterior2nd_Wd Shng      0.000000
# MasVnrType_BrkCmn       -0.006011
# MasVnrType_BrkFace      -0.011697
# MasVnrType_None          0.000341
# MasVnrType_Stone         0.017367
# ExterQual_Ex             0.015779
# ExterQual_Fa            -0.000000
# ExterQual_Gd             0.000000
# ExterQual_TA            -0.012597
# ExterCond_Ex             0.000000
# ExterCond_Fa            -0.004765
# ExterCond_Gd            -0.005739
# ExterCond_Po            -0.000000
# ExterCond_TA             0.011235
# Foundation_BrkTil       -0.001227
# Foundation_CBlock       -0.000000
# Foundation_PConc         0.021797
# Foundation_Slab         -0.000000
# Foundation_Stone         0.000202
# Foundation_Wood         -0.007950
# BsmtQual_0              -0.000000
# BsmtQual_Ex              0.023750
# BsmtQual_Fa              0.000000
# BsmtQual_Gd             -0.006648
# BsmtQual_TA             -0.008458
# BsmtCond_0              -0.000000
# BsmtCond_Fa             -0.008296
# BsmtCond_Gd              0.000747
# BsmtCond_Po             -0.000000
# BsmtCond_TA              0.005545
# BsmtExposure_Av         -0.000868
# BsmtExposure_Gd          0.036846
# BsmtExposure_Mn         -0.001766
# BsmtExposure_No         -0.005294
# BsmtExposure_None       -0.000000
# BsmtFinType1_ALQ         0.003130
# BsmtFinType1_BLQ         0.008883
# BsmtFinType1_GLQ         0.007832
# BsmtFinType1_LwQ        -0.000000
# BsmtFinType1_None       -0.000000
# BsmtFinType1_Rec        -0.005385
# BsmtFinType1_Unf        -0.008188
# BsmtFinType2_ALQ         0.006879
# BsmtFinType2_BLQ        -0.009401
# BsmtFinType2_GLQ         0.000000
# BsmtFinType2_LwQ        -0.000000
# BsmtFinType2_None       -0.000000
# BsmtFinType2_Rec        -0.000000
# BsmtFinType2_Unf         0.004439
# Heating_Floor            0.000000
# Heating_GasA             0.002433
# Heating_GasW             0.004792
# Heating_Grav            -0.019804
# Heating_OthW            -0.000000
# Heating_Wall             0.000000
# HeatingQC_Ex             0.014889
# HeatingQC_Fa            -0.009424
# HeatingQC_Gd             0.000858
# HeatingQC_Po             0.000000
# HeatingQC_TA            -0.006323
# CentralAir_N            -0.022806
# CentralAir_Y             0.022806
# Electrical_FuseA         0.012530
# Electrical_FuseF         0.000000
# Electrical_FuseP        -0.000000
# Electrical_Mix          -0.000000
# Electrical_SBrkr        -0.008341
# KitchenQual_Ex           0.030900
# KitchenQual_Fa          -0.000000
# KitchenQual_Gd          -0.008932
# KitchenQual_None         0.000000
# KitchenQual_TA          -0.011177
# Functional_Maj1         -0.010771
# Functional_Maj2         -0.007062
# Functional_Min1         -0.000000
# Functional_Min2          0.005128
# Functional_Mod          -0.009882
# Functional_Sev           0.000000
# Functional_Typ           0.037472
# FireplaceQu_0           -0.020356
# FireplaceQu_Ex          -0.000000
# FireplaceQu_Fa          -0.000000
# FireplaceQu_Gd           0.007492
# FireplaceQu_Po           0.006573
# FireplaceQu_TA           0.000000
# GarageType_2Types       -0.001004
# GarageType_Attchd        0.008984
# GarageType_Basment      -0.003326
# GarageType_BuiltIn       0.007144
# GarageType_CarPort      -0.002825
# GarageType_Detchd        0.007097
# GarageType_None         -0.005969
# GarageFinish_Fin         0.000269
# GarageFinish_None       -0.005969
# GarageFinish_RFn        -0.000000
# GarageFinish_Unf         0.004212
# GarageQual_0            -0.005969
# GarageQual_Ex            0.000000
# GarageQual_Fa           -0.000000
# GarageQual_Gd            0.010309
# GarageQual_Po           -0.000000
# GarageQual_TA           -0.000000
# GarageCond_0            -0.005969
# GarageCond_Ex            0.000000
# GarageCond_Fa           -0.012155
# GarageCond_Gd            0.000181
# GarageCond_Po            0.000000
# GarageCond_TA            0.004924
# PavedDrive_N            -0.000780
# PavedDrive_P            -0.000000
# PavedDrive_Y             0.005191
# PoolQC_Ex               -0.001409
# PoolQC_Fa               -0.000000
# PoolQC_Gd                0.000000
# PoolQC_None              0.000000
# Fence_GdPrv             -0.001192
# Fence_GdWo              -0.009707
# Fence_MnPrv              0.000000
# Fence_MnWw               0.000000
# Fence_None               0.003594
# MiscFeature_Gar2         0.000000
# MiscFeature_None         0.001713
# MiscFeature_Othr         0.000000
# MiscFeature_Shed        -0.004877
# MiscFeature_TenC         0.000000
# MoSold_1                -0.000000
# MoSold_10                0.002457
# MoSold_11               -0.008303
# MoSold_12                0.005498
# MoSold_2                -0.002030
# MoSold_3                -0.006046
# MoSold_4                -0.002311
# MoSold_5                 0.012507
# MoSold_6                 0.009676
# MoSold_7                 0.005190
# MoSold_8                -0.000000
# MoSold_9                -0.004569
# YrSold_2006              0.009119
# YrSold_2007             -0.002296
# YrSold_2008              0.000000
# YrSold_2009             -0.011304
# YrSold_2010              0.000054
# SaleType_COD            -0.003624
# SaleType_CWD             0.000399
# SaleType_Con             0.000000
# SaleType_ConLD           0.000000
# SaleType_ConLI          -0.006502
# SaleType_ConLw          -0.000000
# SaleType_New             0.025605
# SaleType_Oth             0.000000
# SaleType_WD             -0.024746
# SaleCondition_Abnorml   -0.036520
# SaleCondition_AdjLand    0.000000
# SaleCondition_Alloca     0.000000
# SaleCondition_Family    -0.019148
# SaleCondition_Normal     0.027722
# SaleCondition_Partial    0.016728
# dtype: float64
#
# The model score is 0.9381
#
# Train RMSE: 0.097584
#
# Test RMSE: 0.122209
#
# Diff in RMSE: 0.025

# %% [markdown]
# ## Lasso

# %%
#  alpha           UJ range              np.linspace(1e-4,1e-2,1000)
#  CV          100         10          100
# R2:        0.9366      0.9399      0.9374
# trainRMSE: 0.101363    0.098698    0.100718
# testRMSE:  0.100012    0.100196    0.099977
# diff:b       0.00       0.00         0.00

lassocv = LassoCV(alphas=np.linspace(1e-4,1e-3,1000), normalize=False,
                      max_iter=10000, n_jobs=-1, cv=100)

lassocv.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=lassocv.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=lassocv.predict(x_test)))

print('The best alpha is: {:.2%}\n\nThe lasso intercept is: {:.2f}\n\n{}\n\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    lassocv.alpha_,lassocv.intercept_, pd.Series(lassocv.coef_, index=x_train.columns), lassocv.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(lassocv.predict(test.drop(columns='Id')))}
#             ).to_csv('lasso {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestRegressor(n_estimators=1000,max_depth=10,max_features=0.5, min_samples_split=2, min_samples_leaf=1,n_jobs=-1)
rf.fit(x_train, y_train)

scores = ms.cross_val_score(rf, x_train, y_train, cv=10)

print(scores.mean())

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=rf.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=rf.predict(x_test)))

print('\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    rf.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(rf.predict(test.drop(columns='Id')))}
#             ).to_csv('rf {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)

# 1000 trees
# 0.8395225412896815
# R2: 0.9517
# Train RMSE: 0.088419
# Test RMSE: 0.129310
# Diff in RMSE: 0.041

# %% [markdown]
# ### Looping over max tree depth

# %%
for i in range(1,11):
    rf = RandomForestRegressor(n_estimators=500,max_depth=i,max_features='auto', min_samples_split=2, min_samples_leaf=1,n_jobs=-1)
    rf.fit(x_train, y_train)

    scores = ms.cross_val_score(rf, x_train, y_train, cv=10)
    print('trial with depth = {}'.format(i))
    print(scores.mean())

    trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=rf.predict(x_train)))
    testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=rf.predict(x_test)))

    print('\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
        rf.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# %% [markdown]
# ### Looping over percentage of features for each tree

# %%
for i in np.linspace(0.05,1.0,20):
    rf = RandomForestRegressor(n_estimators=500,max_depth=10,max_features=i, min_samples_split=2, min_samples_leaf=1,n_jobs=-1)
    rf.fit(x_train, y_train)

    scores = ms.cross_val_score(rf, x_train, y_train, cv=10)
    print('trial with depth = {}'.format(i))
    print(scores.mean())

    trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=rf.predict(x_train)))
    testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=rf.predict(x_test)))

    print('\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.2%}\n\n'.format(
        rf.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# %% [markdown]
# ## Gradient Boosting

# %%
gbst = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =111)

gbst.fit(x_train, y_train)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=gbst.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=gbst.predict(x_test)))

print('\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
    gbst.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(gbst.predict(test.drop(columns='Id')))}
#             ).to_csv('gbst {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# Out:
# The model score is 98.66%
#
# Train RMSE: 4.54%
#
# Test RMSE: 12.95%
#
# Diff in RMSE: 8%

# %% [markdown]
# ## XGBoost

# %%
# read in data
dtrain = xgb.DMatrix(x_train)
dtest = xgb.DMatrix(x_test)
# specify parameters via map
param = {'max_depth':2, 'eta':1,'booster':'gbtree', 'objective':'reg:linear' }
num_round = 2
bst = xgb.train(param, dtrain, num_round)
# make prediction
preds = bst.predict(dtest)

trainRMSE = np.sqrt(mean_squared_error(y_true=y_train, y_pred=bst.predict(x_train)))
testRMSE = np.sqrt(mean_squared_error(y_true=y_test, y_pred=bst.predict(x_test)))

print('\nThe model score is {:.2%}\n\nTrain RMSE: {:.2%}\n\nTest RMSE: {:.2%}\n\nDiff in RMSE: {:.0%}\n\n'.format(
        bst.score(x_train, y_train), trainRMSE,testRMSE,(testRMSE - trainRMSE)))

# %% [markdown]
# ## Output csv

# %%
# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(ridcv.predict(test.drop(columns='Id')))}
#             ).to_csv('ridcv {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# pd.DataFrame({'Id': test['Id'], 'SalePrice': np.exp(enet.predict(test.drop(columns='Id')))}
#             ).to_csv('enet {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(lassocv.predict(test.drop(columns='Id')))}
#             ).to_csv('lasso {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(rf.predict(test.drop(columns='Id')))}
#             ).to_csv('rf {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
# pd.DataFrame({'Id':test['Id'],'SalePrice': np.exp(xgb_model.predict(test.drop(columns='Id')))}
#             ).to_csv('xgb_model {}.csv'.format(str(datetime.datetime.now())[:19].replace(':','.')
#                                            ), index=False)
